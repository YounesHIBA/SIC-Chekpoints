# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df = pd.read_csv('titanic-passengers.csv', header='infer',na_values=[' '], sep=';')
df.shape
df.head(4)
#df.tail(5)
#df.shape
#df1=df
#df1.info()
#df.isnull().sum()
df2 = pd.read_csv('titanic-passengers.csv', header='infer',na_values=[' '], sep=';')
df2
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#df['Fare'].value_counts(dropna=True)
df.isnull().sum() 
#Aucune valeur  nul dans la colonne 'fare'
#df['Cabin'].value_counts(dropna=True)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
cf=df.copy()
cf.drop('Cabin',axis=1,inplace=True)
#df
#df.isnull().sum()
cf
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cf['Age'].fillna(df['Age'].mean(), inplace=True)
cf.isnull().sum()
cf['Embarked'].fillna('S', inplace=True)
cf.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
plt.figure(figsize=(10,7), dpi= 80)
sns.distplot(df[df['Sex']=='male']['Age'], kde=True, hist=True)
sns.distplot(df[df['Sex']=='female']['Age'], kde=True, hist=True)
corr=df.corr()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['Age'].corr(df['Pclass'])
# Out:
# -0.3692260153155173

# %%
df.fillna({'Age': round(df['Age'].mean(),1)},inplace=True)

# %%
round(df['Age'].mean(),1)
# Out:
# 29.7

# %%
sns.boxplot(x="Embarked" , y="Fare" , data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889    29.7
# 890    19.0
# Name: Age, Length: 891, dtype: float64

# %%
round(df['Age'])
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889    30.0
# 890    19.0
# Name: Age, Length: 891, dtype: float64

# %%
sns.heatmap( df.corr() , annot=True)

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %% [markdown]
# from this map We say that
# - the two features fare & patch has a good correlaion .
# - Passenger ID & Parch don't have a good correlation , so they are independant.
# - Pclass & Fare have the strongest correlation .

# %%
df.groupby(['Survived'])['Pclass'].mean()
# Out:
# Survived
# No     2.531876
# Yes    1.950292
# Name: Pclass, dtype: float64

# %%
df['Fare'].value_counts(dropna=True)
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 8.0292      1
# 6.9500      1
# 7.8875      1
# 14.0000     1
# 38.5000     1
# Name: Fare, Length: 248, dtype: int64

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('SibSp',axis=1,inplace=True)
#df.drop('Name',axis=1,inplace=True)
#J'ai supprimé les deux colonnes 'Name' & SibSp' car ils ne donnent aucune information pour le survived .

# %%
cf[["Name"]]
# Out:
#                                                   Name
# 0                           Collander, Mr. Erik Gustaf
# 1                              Moen, Mr. Sigurd Hansen
# 2                               Jensen, Mr. Hans Peder
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4                               Davidson, Mr. Thornton
# ..                                                 ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)
# 887                              Sirayanian, Mr. Orsen
# 888                                Cacic, Miss. Marija
# 889                   Petroff, Mr. Pastcho ("Pentcho")
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...
#
# [891 rows x 1 columns]

# %%
cf["Title"] = cf["Name"].str.split(", ").str[1].str.split(".").str[0]
cf["Title"].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Col               2
# Major             2
# Don               1
# Lady              1
# Jonkheer          1
# Mme               1
# Sir               1
# Capt              1
# the Countess      1
# Ms                1
# Name: Title, dtype: int64

# %%
cf
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
cf['Age'].corr(cf['Title'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-29f9e49f53d1> in <module>()
# ----> 1 cf['Age'].corr(cf['Title'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2507         if method in ["pearson", "spearman", "kendall"] or callable(method):
#    2508             return nanops.nancorr(
# -> 2509                 this.values, other.values, method=method, min_periods=min_periods
#    2510             )
#    2511
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# ...

# %%
cf["Sex"]
#df['Age'].corr(df['Sex'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
sex={'male' : 1 ,'female' : 0}
cf['Sex'].replace(sex,inplace=True)
Embarked={'S':0 , 'C':1 , 'Q':2}
cf['Embarked'].replace(Embarked , inplace=True)
cf.head
# Out:
# <bound method NDFrame.head of      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ...

# %%
cf[["Sex","Fare"]].corr()
# Out:
#            Sex      Fare
# Sex   1.000000 -0.182333
# Fare -0.182333  1.000000

# %%
#cf['Sex'].corr(cf['Title'])
cf['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Col               2
# Major             2
# Don               1
# Lady              1
# Jonkheer          1
# Mme               1
# Sir               1
# Capt              1
# the Countess      1
# Ms                1
# Name: Title, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
cf["Title_ratio"] = encoder.fit_transform(cf["Title"])
cf[["Title_ratio","Sex"]].corr()
cf['Age'].corr(cf['Title_ratio'])
# Out:
# 0.2865871710953764

# %%
Title_Dictionary = {

                    " Capt":       "Officer",

                    " Col":        "Officer",

                    " Major":      "Officer",

                      " Dr":         "Officer",

                    " Rev":        "Officer" ,

                    " Jonkheer":   "Royalty",

                    " Don":        "Royalty",

                    " Sir" :       "Royalty",

                   " Lady" :      "Royalty" ,

                  " the Countess": "Royalty",

                    " Dona":       "Royalty",

                    " Mme":        "Miss",

                    " Mlle":       "Miss",

                    " Miss" :      "Miss",

                    " Ms":         "Mrs",

                    " Mr" :        "Mrs",

                    " Mrs" :       "Mrs" ,

                    " Master" :    "Master"

                    }

# %%
cf['Title'].replace(Title_Dictionary , inplace=True)
cf['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Col               2
# Major             2
# Don               1
# Lady              1
# Jonkheer          1
# Mme               1
# Sir               1
# Capt              1
# the Countess      1
# Ms                1
# Name: Title, dtype: int64

# %%
cf.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.035144  0.033207 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.331339  0.083081  0.018443 -0.549500
# Age             0.033207 -0.331339  1.000000 -0.232625 -0.179191  0.091566
# SibSp          -0.057527  0.083081 -0.232625  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.179191  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.091566  0.159651  0.216225  1.000000

# %%
cf
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# ...

# %%
cf["Title"] = encoder.fit_transform(cf["Title"])

# %%
cf.corr()
# Out:
#              PassengerId    Pclass       Sex       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.035144  0.042939  0.033207 -0.057527 -0.001652
# Pclass         -0.035144  1.000000  0.131900 -0.331339  0.083081  0.018443
# Sex             0.042939  0.131900  1.000000  0.084153 -0.114631 -0.245489
# Age             0.033207 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# SibSp          -0.057527  0.083081 -0.114631 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.018443 -0.245489 -0.179191  0.414838  1.000000
# Fare            0.012658 -0.549500 -0.182333  0.091566  0.159651  0.216225
# Embarked       -0.030467  0.045702 -0.116569  0.007461 -0.059961 -0.078665
# Title           0.035120  0.029099  0.250075  0.286587 -0.200046 -0.126422
# Title_ratio     0.035120  0.029099  0.250075  0.286587 -0.200046 -0.126422
#
#                  Fare  Embarked     Title  Title_ratio
# PassengerId  0.012658 -0.030467  0.035120     0.035120
# ...

# %%
cf[["Title","Sex"]].corr()
# Out:
#           Title       Sex
# Title  1.000000  0.250075
# Sex    0.250075  1.000000

# %%
cf['Age'].corr(cf['Title'])
# Out:
# 0.2865871710953764

# %%
cf['FamilySize']=cf['SibSp']+cf['Parch']
cf
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# ...

# %%
Survived={'Yes' : 1 , 'No' :0 }
cf['Survived'].replace(Survived , inplace=True)

# %%
cf.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.033207 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.069809 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.331339  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.084153 -0.114631
# Age             0.033207 -0.069809 -0.331339  0.084153  1.000000 -0.232625
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.232625  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.179191  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.091566  0.159651
# Embarked       -0.030467  0.106811  0.045702 -0.116569  0.007461 -0.059961
# Title           0.035120 -0.193635  0.029099  0.250075  0.286587 -0.200046
# Title_ratio     0.035120 -0.193635  0.029099  0.250075  0.286587 -0.200046
# ...

# %%
cf['FamilySize'].corr(cf['Survived'])
# Out:
# 0.016638989282745268

# %%
cf['FamilySize'].corr(cf['Age'])
# Out:
# -0.2485117254803858

# %%
sns.heatmap( cf.corr())

# %%
#

# %% [markdown]
# D'après les résultats obtenus on peut dire que cette feature " FamilySize " nous donne aucune information vraimment fiable o décessive qui nous aider à prendre la décision en ce qui concerne "Survived" or no , car ne sont pas vraimment corrélés
